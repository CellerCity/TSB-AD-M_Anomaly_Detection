# %%
from huggingface_hub import snapshot_download
# Download the entire repository
snapshot_download(repo_id="AtikAhamed/TFRBench", repo_type="dataset", local_dir="./TFRBench")
# Out:
# Fetching 12 files: 100%|██████████| 12/12 [00:01<00:00, 10.60it/s]
# 'C:\\Files\\MTP Code Local Files\\MTP_SEM_3_LOCAL_FILES\\TFRBench'
